# %%
import os
os.chdir(r'C:\Users\Derrick\Documents\Scripts\Python\StockRelated')

import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
import datetime as dt

def scrape_news_text(news_url): 
    news_html = requests.get(news_url).content 
    news_soup = BeautifulSoup(news_html , 'lxml') 
    titles = news_soup.find_all('title')
    title = [title.text for title in titles if title.text is not None]
    spans = news_soup.find_all('span')
    publishedDatetime = [span.get('content') for span in spans if span.get('content') is not None]
    paragraphs = [par.text for par in news_soup.find_all('p')]
    news_text = '\n'.join(paragraphs) 
    try:
        return title[0], publishedDatetime[0], news_text
    except:
        print('try on return empty')
        pass

def get_news_urls(links_site):
    resp = requests.get(links_site) 
    if not resp.ok:
        return None 
    html = resp.content
    soup = BeautifulSoup(html , 'lxml')
    links = soup.find_all('a')
 
    urls = [link.get('href') for link in links]
    urls = [url for url in urls if url is not None]
    news_urls = [url for url in urls if '/article/' in url]
 
    return news_urls


def scrape_all_articles(ticker , upper_page_limit = 1): 
    landing_site = 'http://www.nasdaq.com/symbol/' + ticker + '/news-headlines' 
    all_news_urls = get_news_urls(landing_site) 
    current_urls_list = all_news_urls.copy()
 
    index = 2
    while (current_urls_list is not None) and (current_urls_list != []) and \
        (index <= upper_page_limit):
        
        PreUrl = current_urls_list[-1]        
        current_site = landing_site + '?page=' + str(index)
        current_urls_list = get_news_urls(current_site)        
        CurUrl = current_urls_list[-1]       
        
        if PreUrl==CurUrl:
            break
        else: 
            all_news_urls = all_news_urls + current_urls_list     
            index = index + 1
    
    all_news_urls = list(set(all_news_urls))
    
    ''' getting contents from urls'''
    all_articles = []
    for news_url in all_news_urls:
        try:
            article = scrape_news_text(news_url)
            all_articles.append(article)
        except:
            print('This url can''t be extracted: \n', news_url )

    all_articles  = [article for article in all_articles if article is not None]
    #return all_articles
    df1 = pd.DataFrame(all_articles, columns =['Title','PublishedDT','Content'])
    return df1

def SelectParagraphs(ContentText, ticker):
    paras = ContentText.split('\n')
    KeyParas = [para for para in paras if ticker in para]
    return " ".join(KeyParas)


def nsdaqNewsScripting(Ticker):
    #Ticker1 = Ticker
    print('nsdaqNewsScripting')
    all_articles = scrape_all_articles(Ticker.lower() , upper_page_limit = 200)

    all_articles['PublishedDT'] = pd.to_datetime(all_articles['PublishedDT'])
    all_articles = all_articles.sort_values(by='PublishedDT')

    all_articles['Content'] = all_articles['Content'].str.replace('Join the Nasdaq Community today and get free, instant access to portfolios, stock ratings, real-time alerts, and more!','')
    all_articles['Title'] = all_articles['Title'].str.replace('- Nasdaq.com','')


    all_articles['TickerInTitle'] = 0
    all_articles['TickerInTitle'][all_articles['Title'].str.contains(Ticker)] = 1

    all_articles['TickerInContent'] = 0
    all_articles['TickerInContent'][all_articles['Content'].str.contains(Ticker)] = 1

    all_articles['KeyParagraphs'] =   all_articles.apply(lambda x: SelectParagraphs(x['Content'], Ticker), axis=1 )

    fileName = Ticker +  'NewsForNLP_'+ dt.datetime.now().strftime("%Y%m%d")  +'.xlsx'

    all_articles[['PublishedDT','TickerInTitle','TickerInContent', 'Title', 'Content','KeyParagraphs']].to_excel(fileName, index=False)

    return all_articles

# %%
TickerList = pd.read_csv('companylist.csv')
TickerList  = TickerList['Symbol']

# %%
pd.options.mode.chained_assignment = None

for ticker in TickerList[396:400]:
    print('Now processing ', ticker)
    try:
        all_articles = nsdaqNewsScripting(ticker)
    except:
        print('\t', ticker, ' cannot be extracted')
# Out:
# Now processing  NXPI
# nsdaqNewsScripting
# 	 NXPI  cannot be extracted
# Now processing  OIIM
# nsdaqNewsScripting
# 	 OIIM  cannot be extracted
# Now processing  OCLR
# nsdaqNewsScripting
# 	 OCLR  cannot be extracted
# Now processing  OKTA
# nsdaqNewsScripting
# 	 OKTA  cannot be extracted

# %%
all_articles.head()
# Out:
#                                                 Title         PublishedDT  \
# 10  How Data Is Making The U.S. Stock Market Open ... 2018-07-27 07:31:12
# 7             Friday's ETF with Unusual Volume: URTH  2018-12-07 07:01:31
# 2   AMD Stock Up Almost 100% and Still Has Fight I... 2018-12-07 08:15:33
# 4   Why Advanced Micro Devices Stock Surged 17% in... 2018-12-10 06:14:00
# 8   Support Will Hold for Micron Stock After Earni... 2018-12-10 08:27:31
#
#                                               Content  TickerInTitle  \
# 10  \n\nFor most Americans, financial security, or...              0
# 7   \nThe iShares MSCI World ETF ( URTH  ) is seei...              0
# 2   \n\nInvestorPlace - Stock Market News, Stock A...              1
# 4   \n \nShares of   Advanced Micro Devices    (NA...              0
# 8   \n\nInvestorPlace - Stock Market News, Stock A...              0
#
#     TickerInContent                                      KeyParagraphs
# 10                0
# 7                 0
# 2                 1  This has been an epic year for the stock marke...
# 4                 1  Shares of   Advanced Micro Devices    (NASDAQ:...
# 8                 1  That said, Micron stock does have a potential ...

# %%
TickerList[228]
# Out:
# 'JOB'

# %%
TickerList = pd.read_csv('companylist.csv')

# %%
TickerList[:50]
# Out:
#    Symbol                                   Name   LastSale     MarketCap  \
# 0    VNET                   21Vianet Group, Inc.     9.6100  5.963649e+08
# 1    TWOU                               2U, Inc.    57.8400  3.350244e+09
# 2     DDD                 3D Systems Corporation    12.4800  1.424973e+09
# 3    JOBS                            51job, Inc.    64.0000  2.331915e+09
# 4    WUBA                            58.com Inc.    57.2400  8.479463e+09
# 5    EGHT                                8x8 Inc    18.9700  1.809191e+09
# 6    ATEN                     A10 Networks, Inc.     6.2900  4.641920e+08
# 7     AAN                     Aaron&#39;s,  Inc.    47.5300  3.449647e+09
# 8    ACIA            Acacia Communications, Inc.    41.3900  1.673946e+09
# 9    ACIW                    ACI Worldwide, Inc.    28.9900  3.362250e+09
# 10   ACMR                     ACM Research, Inc.    11.0000  1.760411e+08
# 11   ATVI               Activision Blizzard, Inc    52.5600  4.010595e+10
# 12    ATU                    Actuant Corporation    25.1000  1.531502e+09
# 13   IOTS        Adesto Technologies Corporation     5.1400  1.504400e+08
# 14   ADBE                             Adobe Inc.   249.0900  1.215892e+11
# 15    AMD           Advanced Micro Devices, Inc.    21.4300  2.141730e+10
# 16    AER                   Aercap Holdings N.V.    52.6300  7.734561e+09
# 17    ACY                      AeroCentury Corp.    11.9416  1.691765e+07
# 18   HIVE                Aerohive Networks, Inc.     3.6500  2.027773e+08
# 19   AGYS                         Agilysys, Inc.    16.7000  3.929228e+08
# 20   AGMH                AGM Group Holdings Inc.    38.3600  8.176839e+08
# 21     AL                  Air Lease Corporation    38.4900  4.133322e+09
# 22    AYR                      Aircastle Limited    18.5700  1.415542e+09
# 23   AIRG                          Airgain, Inc.    12.7200  1.261151e+08
# 24   AMCN                     AirMedia Group Inc     0.2859  1.291632e+07
# 25   ALRM               Alarm.com Holdings, Inc.    49.8400  2.392476e+09
# 26   ALYA                     Alithya Group inc.     3.7000  1.790942e+08
# 27   ALLT              Allot Communications Ltd.     6.7000  2.258860e+08
# 28   MDRX  Allscripts Healthcare Solutions, Inc.    10.1500  1.773349e+09
# 29   AOSL  Alpha and Omega Semiconductor Limited    11.0700  2.633325e+08
# 30   GOOG                          Alphabet Inc.  1088.3000  7.568756e+11
# 31  GOOGL                          Alphabet Inc.  1094.5800  7.612432e+11
# 32   AABA                            Altaba Inc.    64.4200  3.881932e+10
# 33   ALTR                Altair Engineering Inc.    31.3200  2.202686e+09
# 34    AYX                          Alteryx, Inc.    58.3600  3.582325e+09
# 35   AMBA                        Ambarella, Inc.    33.7500  1.081910e+09
# 36   AMBR                       Amber Road, Inc.     8.6200  2.395691e+08
# 37    DOX                         Amdocs Limited    64.7600  9.159913e+09
# 38   AMRH                   Ameri Holdings, Inc.     0.2475  5.661178e+06
# 39  AMRHW                   Ameri Holdings, Inc.     0.0301  0.000000e+00
# 40  AMSWA                American Software, Inc.    10.9500  3.384243e+08
# 41   AMKR                 Amkor Technology, Inc.     6.7200  1.609661e+09
# 42    AMN            AMN Healthcare Services Inc    64.2200  3.009855e+09
# 43   ASYS                   Amtech Systems, Inc.     5.5700  8.348174e+07
# 44    ADI                   Analog Devices, Inc.    89.5200  3.313668e+10
# 45   PLAN                          Anaplan, Inc.    26.1400  0.000000e+00
# 46   ANSS                            ANSYS, Inc.   159.4000  1.331947e+10
# 47    APY                     Apergy Corporation    35.0600  2.711569e+09
# 48   APPF                         AppFolio, Inc.    61.8200  2.117368e+09
# 49   APPN                     Appian Corporation    29.1900  1.858556e+09
#
#      ADR TSO IPOyear      Sector  \
# 0   62056704    2011  Technology
# 1        n/a    2014  Technology
# 2        n/a     n/a  Technology
# 3   36436171    2004  Technology
# 4        n/a    2013  Technology
# 5        n/a     n/a  Technology
# 6        n/a    2014  Technology
# 7        n/a     n/a  Technology
# 8        n/a    2016  Technology
# 9        n/a     n/a  Technology
# 10       n/a    2017  Technology
# 11       n/a     n/a  Technology
# 12       n/a     n/a  Technology
# 13       n/a    2015  Technology
# 14       n/a    1986  Technology
# 15       n/a     n/a  Technology
# 16       n/a    2006  Technology
# 17       n/a     n/a  Technology
# 18       n/a    2014  Technology
# 19       n/a     n/a  Technology
# 20       n/a    2018  Technology
# 21       n/a    2011  Technology
# 22       n/a    2006  Technology
# 23       n/a    2016  Technology
# 24  45177749    2007  Technology
# 25       n/a    2015  Technology
# 26       n/a     n/a  Technology
# 27       n/a    2006  Technology
# 28       n/a     n/a  Technology
# 29       n/a    2010  Technology
# 30       n/a    2004  Technology
# 31       n/a     n/a  Technology
# 32       n/a     n/a  Technology
# 33       n/a    2017  Technology
# 34       n/a    2017  Technology
# 35       n/a    2012  Technology
# 36       n/a    2014  Technology
# 37       n/a     n/a  Technology
# 38       n/a     n/a  Technology
# 39       n/a     n/a  Technology
# 40       n/a     n/a  Technology
# 41       n/a    1998  Technology
# 42       n/a     n/a  Technology
# 43       n/a     n/a  Technology
# 44       n/a     n/a  Technology
# 45       n/a    2018  Technology
# 46       n/a    1996  Technology
# 47       n/a    2018  Technology
# 48       n/a    2015  Technology
# 49       n/a    2017  Technology
#
#                                              Industry  \
# 0     Computer Software: Programming, Data Processing
# 1             Computer Software: Prepackaged Software
# 2             Computer Software: Prepackaged Software
# 3                     Diversified Commercial Services
# 4     Computer Software: Programming, Data Processing
# 5                                        EDP Services
# 6                   Computer Communications Equipment
# 7                     Diversified Commercial Services
# 8                                      Semiconductors
# 9             Computer Software: Prepackaged Software
# 10                    Industrial Machinery/Components
# 11            Computer Software: Prepackaged Software
# 12                    Industrial Machinery/Components
# 13                                     Semiconductors
# 14            Computer Software: Prepackaged Software
# 15                                     Semiconductors
# 16                    Diversified Commercial Services
# 17                    Diversified Commercial Services
# 18                                       EDP Services
# 19                                       EDP Services
# 20                                       EDP Services
# 21                    Diversified Commercial Services
# 22                    Diversified Commercial Services
# 23  Radio And Television Broadcasting And Communic...
# 24                                        Advertising
# 25            Computer Software: Prepackaged Software
# 26    Computer Software: Programming, Data Processing
# 27                  Computer Communications Equipment
# 28                                       EDP Services
# 29                                     Semiconductors
# 30    Computer Software: Programming, Data Processing
# 31    Computer Software: Programming, Data Processing
# 32                                       EDP Services
# 33            Computer Software: Prepackaged Software
# 34            Computer Software: Prepackaged Software
# 35                                     Semiconductors
# 36            Computer Software: Prepackaged Software
# 37                                       EDP Services
# 38                                     Semiconductors
# 39                                     Semiconductors
# 40            Computer Software: Prepackaged Software
# 41                                     Semiconductors
# 42                              Professional Services
# 43                    Industrial Machinery/Components
# 44                                     Semiconductors
# 45            Computer Software: Prepackaged Software
# 46            Computer Software: Prepackaged Software
# 47                    Industrial Machinery/Components
# 48            Computer Software: Prepackaged Software
# 49            Computer Software: Prepackaged Software
#
#                           Summary Quote  Unnamed: 9
# 0    https://www.nasdaq.com/symbol/vnet         NaN
# 1    https://www.nasdaq.com/symbol/twou         NaN
# 2     https://www.nasdaq.com/symbol/ddd         NaN
# 3    https://www.nasdaq.com/symbol/jobs         NaN
# 4    https://www.nasdaq.com/symbol/wuba         NaN
# 5    https://www.nasdaq.com/symbol/eght         NaN
# 6    https://www.nasdaq.com/symbol/aten         NaN
# 7     https://www.nasdaq.com/symbol/aan         NaN
# 8    https://www.nasdaq.com/symbol/acia         NaN
# 9    https://www.nasdaq.com/symbol/aciw         NaN
# 10   https://www.nasdaq.com/symbol/acmr         NaN
# 11   https://www.nasdaq.com/symbol/atvi         NaN
# 12    https://www.nasdaq.com/symbol/atu         NaN
# 13   https://www.nasdaq.com/symbol/iots         NaN
# 14   https://www.nasdaq.com/symbol/adbe         NaN
# 15    https://www.nasdaq.com/symbol/amd         NaN
# 16    https://www.nasdaq.com/symbol/aer         NaN
# 17    https://www.nasdaq.com/symbol/acy         NaN
# 18   https://www.nasdaq.com/symbol/hive         NaN
# 19   https://www.nasdaq.com/symbol/agys         NaN
# 20   https://www.nasdaq.com/symbol/agmh         NaN
# 21     https://www.nasdaq.com/symbol/al         NaN
# 22    https://www.nasdaq.com/symbol/ayr         NaN
# 23   https://www.nasdaq.com/symbol/airg         NaN
# 24   https://www.nasdaq.com/symbol/amcn         NaN
# 25   https://www.nasdaq.com/symbol/alrm         NaN
# 26   https://www.nasdaq.com/symbol/alya         NaN
# 27   https://www.nasdaq.com/symbol/allt         NaN
# 28   https://www.nasdaq.com/symbol/mdrx         NaN
# 29   https://www.nasdaq.com/symbol/aosl         NaN
# 30   https://www.nasdaq.com/symbol/goog         NaN
# 31  https://www.nasdaq.com/symbol/googl         NaN
# 32   https://www.nasdaq.com/symbol/aaba         NaN
# 33   https://www.nasdaq.com/symbol/altr         NaN
# 34    https://www.nasdaq.com/symbol/ayx         NaN
# 35   https://www.nasdaq.com/symbol/amba         NaN
# 36   https://www.nasdaq.com/symbol/ambr         NaN
# 37    https://www.nasdaq.com/symbol/dox         NaN
# 38   https://www.nasdaq.com/symbol/amrh         NaN
# 39  https://www.nasdaq.com/symbol/amrhw         NaN
# 40  https://www.nasdaq.com/symbol/amswa         NaN
# 41   https://www.nasdaq.com/symbol/amkr         NaN
# 42    https://www.nasdaq.com/symbol/amn         NaN
# 43   https://www.nasdaq.com/symbol/asys         NaN
# 44    https://www.nasdaq.com/symbol/adi         NaN
# 45   https://www.nasdaq.com/symbol/plan         NaN
# 46   https://www.nasdaq.com/symbol/anss         NaN
# 47    https://www.nasdaq.com/symbol/apy         NaN
# 48   https://www.nasdaq.com/symbol/appf         NaN
# 49   https://www.nasdaq.com/symbol/appn         NaN

# %%
TickerList['Symbol'][380:420]
# Out:
# 380    NATI
# 381    NPTN
# 382    NETE
# 383    NTAP
# 384    NTCT
# 385    NTWK
# 386    NEWR
# 387    NXGN
# 388    NICE
# 389    LASR
# 390     NOK
# 391    NUAN
# 392    NTNX
# 393    NVEC
# 394     NVT
# 395    NVDA
# 396    NXPI
# 397    OIIM
# 398    OCLR
# 399    OKTA
# 400    OMCL
# 401     OMC
# 402      ON
# 403    OTIV
# 404     OSS
# 405    OSPN
# 406    OOMA
# 407    OTEX
# 408    ORCL
# 409    OSIS
# 410    PFIN
# 411    PAGS
# 412    PANW
# 413    TEUM
# 414    PCYG
# 415     PKE
# 416    PAYC
# 417    PCTY
# 418    PCTI
# 419    PDFS
# Name: Symbol, dtype: object
